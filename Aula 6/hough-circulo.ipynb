# %% [markdown]
# Transformada de Hough para detecção de círculo
# ====
# ---

# %% [markdown]
# Importação as bibliotecas:

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Detectando círculos na imagem **coins.png**:

# %%
#Carregando a imagem
img = cv.imread('coins.png',0)
blur = cv.medianBlur(img,5)
edges = cv.Canny(blur,150,250,apertureSize = 3)
cimg = cv.cvtColor(img,cv.COLOR_GRAY2BGR)
circles = cv.HoughCircles(edges,cv.HOUGH_GRADIENT,1,20,
                            param1=50,param2=30,minRadius=0,maxRadius=0)
circles = np.uint16(np.around(circles))

#Desenhando o círculos na imagem
for i in circles[0,:]:
    #Desenhando a parte externa do círculo
    cv.circle(cimg,(i[0],i[1]),i[2],(0,255,0),2)
    #Desenhando o centro dos círculos
    cv.circle(cimg,(i[0],i[1]),2,(0,0,255),3)
    print('Posição do círculo: (%d,%d)' % (i[0],i[1]))
    print('Raio: %d' %i[2])

print('Quantidade de círculos: ', circles.shape[1])

#Exibição dos resultados
plt.figure(figsize=(10,7))
plt.subplot(131), plt.title("Original"), plt.imshow(img,'gray'), plt.axis('off')
plt.subplot(132), plt.title("Canny Edge Detection"), plt.imshow(edges,'gray'), plt.axis('off')
plt.subplot(133), plt.title("Hough Transform Circle"), plt.imshow(cimg, 'gray'), plt.axis('off')
plt.show()

# %% [markdown]
# Detectando círculos na imagem **circles.png**:

# %%
#Carregando a imagem
img = cv.imread('circles.png',0)
blur = cv.medianBlur(img,3)
edges = cv.Canny(blur,150,250,apertureSize = 3)
cimg = cv.cvtColor(img,cv.COLOR_GRAY2BGR)
circles = cv.HoughCircles(edges,cv.HOUGH_GRADIENT,1,20,
                            param1=50,param2=10,minRadius=10,maxRadius=30)
circles = np.uint16(np.around(circles))

#Desenhando o círculos na imagem
for i in circles[0,:]:
    #Desenhando a parte externa do círculo
    cv.circle(cimg,(i[0],i[1]),i[2],(0,255,0),2)
    #Desenhando o centro dos círculos
    cv.circle(cimg,(i[0],i[1]),2,(0,0,255),3)
    print('Posição do círculo: (%d,%d)' % (i[0],i[1]))
    print('Raio: %d' %i[2])

print('Quantidade de círculos: ', circles.shape[1])

#Exibição dos resultados
plt.figure(figsize=(10,7))
plt.subplot(131), plt.title("Original"), plt.imshow(img,'gray'), plt.axis('off')
plt.subplot(132), plt.title("Canny Edge Detection"), plt.imshow(edges,'gray'), plt.axis('off')
plt.subplot(133), plt.title("Hough Transform Circle"), plt.imshow(cimg, 'gray'), plt.axis('off')
plt.show()
# Out:
# Posição do círculo: (36,36)
# Raio: 20
# Posição do círculo: (178,184)
# Raio: 20
# Posição do círculo: (118,222)
# Raio: 19
# Posição do círculo: (184,218)
# Raio: 19
# Posição do círculo: (124,114)
# Raio: 19
# Posição do círculo: (72,38)
# Raio: 18
# Posição do círculo: (94,166)
# Raio: 19
# Posição do círculo: (38,72)
# Raio: 19
# Posição do círculo: (150,204)
# Raio: 19
# Posição do círculo: (94,132)
# Raio: 19
# Posição do círculo: (98,96)
# Raio: 19
# Posição do círculo: (122,186)
# Raio: 19
# Posição do círculo: (72,72)
# Raio: 18
# Quantidade de círculos:  13
